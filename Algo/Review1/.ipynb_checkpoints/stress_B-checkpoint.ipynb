# %%
import subprocess
import timeit
from random import choice, seed

SAMPLES_NUM = 10
ALPHA_SIZE = 26
STRLEN = 1000
SAMPLE_LEN = 100

seed()

def testgen(num=SAMPLES_NUM, str_len=STRLEN, alpha=ALPHA_SIZE):
    chars = [chr(ord('a') + i) for i in range(ALPHA_SIZE)]
    with open('B.in', 'w') as ftest:
        ftest.write(str(str_len) + " " + str(num) + " " + str(alpha) + "\n")
        for i in range(num):
            sample = ''
            for k in range(choice(range(SAMPLE_LEN, SAMPLE_LEN + 1))):
                sample += choice(chars)
            ftest.write(sample + '\n')        

def timerun(num=SAMPLES_NUM, str_len=STRLEN, alpha=ALPHA_SIZE, repeats=1):
    testgen(num, str_len, alpha)
    t = %timeit -o -q -n 1 -r $repeats subprocess.check_output(["./a.out"])
    return t.best

# %%
found = False
while not found:
    t = timerun()
    if t > 0.1:
        print(t)
        found = True
# Out:
# 0.12396352500945795

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(1, 102, 20)
y = [timerun(int(num)) for num in x]
line, = plt.plot(x, y, '--', linewidth=2, color='green')

plt.show()

# %%
x = np.linspace(10, 1000, 10)
y = [timerun(str_len=int(num)) for num in x]
line, = plt.plot(x, y, '--', linewidth=2, color='red')

plt.show()

# %%
x = np.linspace(1, 26)
y = [timerun(alpha=int(num)) for num in x]
line, = plt.plot(x, y, '-', linewidth=2, color='blue')

plt.show()

# %%
# только построение

x = np.linspace(1, 102, 10)
y = [timerun(num=int(num), repeats=100) for num in x]
line, = plt.plot(x, y, '-', linewidth=1, color='green')

plt.show()


x = np.linspace(1, 26, 10)
y = [timerun(alpha=int(num), repeats=100) for num in x]
line, = plt.plot(x, y, '-', linewidth=1, color='blue')

plt.show()

# %%
x = range(1, 11)
y = [timerun(num=num, repeats=1) for num in x]
line, = plt.plot(x, y, '-', linewidth=1, color='green')
plt.show()

x = range(2, 27)
y = [timerun(alpha=num, repeats=1) for num in x]
line, = plt.plot(x, y, '-', linewidth=1, color='blue')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-1ce443e1c944> in <module>()
#       1 x = range(1, 11)
# ----> 2 y = [timerun(num=num, repeats=10) for num in x]
#       3 line, = plt.plot(x, y, '-', linewidth=1, color='green')
#       4 plt.show()
#       5
#
# <ipython-input-49-1ce443e1c944> in <listcomp>(.0)
#       1 x = range(1, 11)
# ----> 2 y = [timerun(num=num, repeats=10) for num in x]
#       3 line, = plt.plot(x, y, '-', linewidth=1, color='green')
#       4 plt.show()
#       5
#
# <ipython-input-44-ec26501974fd> in timerun(num, str_len, alpha, repeats)
#      22 def timerun(num=SAMPLES_NUM, str_len=STRLEN, alpha=ALPHA_SIZE, repeats=1):
#      23     testgen(num, str_len, alpha)
# ---> 24     t = get_ipython().magic('timeit -o -q -n 1 -r $repeats subprocess.check_output(["./a.out"])')
#      25     return t.best
#
# /usr/local/lib/python3.4/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2203         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2204         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2205         return self.run_line_magic(magic_name, magic_arg_s)
#    2206
#    2207     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.4/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2124                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2125             with self.builtin_trap:
# -> 2126                 result = fn(*args,**kwargs)
#    2127             return result
#    2128
#
# /usr/local/lib/python3.4/dist-packages/IPython/core/magics/execution.py in timeit(self, line, cell)
#
# /usr/local/lib/python3.4/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /usr/local/lib/python3.4/dist-packages/IPython/core/magics/execution.py in timeit(self, line, cell)
#    1014                     break
#    1015                 number *= 10
# -> 1016         all_runs = timer.repeat(repeat, number)
#    1017         best = min(all_runs) / number
#    1018         if not quiet :
#
# /usr/lib/python3.4/timeit.py in repeat(self, repeat, number)
#     210         r = []
#     211         for i in range(repeat):
# --> 212             t = self.timeit(number)
#     213             r.append(t)
#     214         return r
#
# /usr/lib/python3.4/timeit.py in timeit(self, number)
#     182         gc.disable()
#     183         try:
# --> 184             timing = self.inner(it, self.timer)
#     185         finally:
#     186             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# /usr/lib/python3.4/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     607     with Popen(*popenargs, stdout=PIPE, **kwargs) as process:
#     608         try:
# --> 609             output, unused_err = process.communicate(inputdata, timeout=timeout)
#     610         except TimeoutExpired:
#     611             process.kill()
#
# /usr/lib/python3.4/subprocess.py in communicate(self, input, timeout)
#     945                 self.stdin.close()
#     946             elif self.stdout:
# --> 947                 stdout = _eintr_retry_call(self.stdout.read)
#     948                 self.stdout.close()
#     949             elif self.stderr:
#
# /usr/lib/python3.4/subprocess.py in _eintr_retry_call(func, *args)
#     489     while True:
#     490         try:
# --> 491             return func(*args)
#     492         except InterruptedError:
#     493             continue
#
# KeyboardInterrupt:
